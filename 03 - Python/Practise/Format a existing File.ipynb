# %%
import re
import pandas as pd
data = open("wchat2.txt")
data = data.readlines()
i=0
Stdict = {"Name":[],
          "Roll_no":[],
          "Time": [],
          "Contact_no":[],
          "Email":[]  }
## Defining regression Expression for Data fetching
Nameregex = "[A-z]\w+\s[A-z]\w+"
Timeregex = "\d{2}:\d{2} [PMAMpmam]{2}"
Rollregex = " *AI[-\s0-9\s]{6,7}|Roll No:[\s0-9\s]{6} "   
Mobileregex = "\d\d\s\d\d\d\s\d{7}| [0-9]{11,12}| [0-9]{4}-[0-9]{7}|[0-9]{11,12}"   
Mailregex = "[A-z0-9].[A-z0-9]\w[@][A-z].[A-z]*"
## Loop throught Data
for m in data:
        name = re.findall(Nameregex,data[i])
        time  = re.findall(Timeregex, data[i])
        rollno=re.findall(Rollregex, data[i])
        email =re.findall(Mailregex, data[i])
        mobile = re.findall(Mobileregex, data[i])
        ## Rectifying Mobile Data
        b=mobile[0]
        b=b.replace(" ","").replace("+","").replace("-","")
        if len(b) == 11:
            tempmobile = "+92-"+b[1:len(b)-7]+"-"+b[len(b)-7:len(b)]
        if len(b) == 12:
            tempmobile = "+92-"+b[2:len(b)-7]+"-"+b[len(b)-7:len(b)]
        if len(b) == 13:
            tepmobile = "+92-"+b[3:len(b)-7]+"-"+b[len(b)-7:len(b)]
        mobile = [tempmobile]
        
        ## Rectifying Name Data
        try:
            name = [name[0].replace(" ","").replace("Roll No","").replace("Mobile No","").\
                    replace("AI","").replace("CR","").replace("IBT","").replace("rollno","")]
        except (IndexError):
            print('hi')
        ## Rectifying Email Data
        if email == []:
            email=['None']
        print(data[i])
        print(name),print(rollno),print(mobile),print(time),print(email)
        ## Adding to Dictionary
        Stdict["Name"].append(name[0])
        Stdict["Roll_no"].append(rollno[0])
        Stdict["Time"].append(time[0])
        Stdict["Contact_no"].append(mobile[0])
        Stdict["Email"].append(email[0])
       
        if(i<(len(data)-1)):
            i =i+1
## Creating Dataframe After Looping and cleaning Data
StudendData = pd.DataFrame({k:pd.Series(v) for k,v in Stdict.items()})
##{k:len(v) for k,v in Stdict.items()}
StudendData.head(29)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [57], in <cell line: 18>()
#      23 mobile = re.findall(Mobileregex, data[i])
#      24 ## Rectifying Mobile Data
# ---> 25 b=mobile[0]
#      26 b=b.replace(" ","").replace("+","").replace("-","")
#      27 if len(b) == 11:
#
# IndexError: list index out of range

# %%
StudendData
# Out:
#                  Name          Roll_no      Time       Contact_no  \
# 0          IqbalAhmed        AI-46214   11:05 pm  +92-345-3113993
# 1        MuhammadSaad        AI46190 0  11:12 pm  +92-304-3184681
# 2             Shahzad        AI-46165   11:12 pm  +92-300-2303175
# 3                Sami        AI- 40483  11:12 pm  +92-315-2935701
# 4        TalhaMehfooz        AI-40211   11:13 pm  +92-334-2995610
# 5      MuhammadMohsin         AI-53993  11:13 pm  +92-335-3271054
# 6           Hidayatur         AI-6546   11:13 pm  +92-345-2541450
# 7      MuhammadFaizan         AI 40939  11:13 pm  +92-316-2688657
# 8     SaadAhmedRollNo         AI-47242  11:13 pm  +92-344-2226632
# 9         comMobileno         AI-20145  11:13 pm  +92-313-1145255
# 10       AbdulRasheed         AI-40154  11:13 pm  +92-323-2900066
# 11    MuhammadZeeshan        AI-400250  11:14 pm  +92-315-3727169
# 12        Ahmedsaleem         AI-44378  11:14 pm  +92-342-3392795
# 13           AliNasir  Roll No: 44365   11:14 pm  +92-331-2147373
# 14         HamzaAhmed        AI-40591   11:14 pm  +92-333-3120597
# 15             Zubair        AI- 40200  11:14 pm  +92-316-1448439
# 16          IrfanRoll        AI-45055   11:14 pm  +92-315-2185186
# 17        BasharatAli         AI-46716  11:15 pm  +92-312-2093412
# 18  MuhammadusamaRoll         AI-43985  11:15 pm  +92-344-1802958
# 19         Farazuddin        AI-44226-  11:15 pm  +92-312-8525358
# 20       SyedMuhammad        AI-40222   11:15 pm  +92-334-3523966
# 21          AbdulSami        AI-40352   11:15 pm  +92-324-2824117
# 22          UmairTaqi        AI-46155   11:16 pm  +92-312-2296999
# 23         AtiqRazaID         AI-42612  11:16 pm  +92-323-2553599
# 24         AhsanUddin        AI-435050  11:16 pm  +92-334-0378290
# 25             FURQAN         AI-40277  11:16 pm  +92-312-0004695
# 26         SyedSalman        AI-40969   11:17 pm  +92-306-2462926
# 27       SyedMuhammad         AI-47456  11:17 pm  +92-309-2655755
# 28            Mehmood        AI-41824   11:17 pm  +92-302-8289423
#
#            Email
# 0     ed91@gmail
# 1     ad50@gmail
# 2     hmed@gmail
# 3     2872@gmail
# 4     tm47@gmail
# 5     0700@gmail
# 6           None
# 7     m476@gmail
# 8     ad96@gmail
# 9     1996@gmail
# 10          None
# 11          None
# 12    2122@gmail
# 13    1997@gmail
# 14    2000@gmail
# 15    0316@gmail
# 16    k786@gmail
# 17    ad24@gmail
# 18    h315@gmail
# 19    ad92@gmail
# 20          None
# 21    in82@gmail
# 22    qi48@gmail
# 23    iq05@gmail
# 24          None
# 25    wati@gmail
# 26          None
# 27    am19@gmail
# 28  eman@hotmail

# %%
with open("wchat3.txt","r") as file: f = file.read()
id = []
for line in f:
#     print(line)
    if line.startswith("[:"):
        print('hello')
#         id.append(f.line[2:])
print(id)
# Out:
# []

# %%
mlist = []
for x in f:
    eindex = x.index("[")
    print(eindex)
#     if x.startswith("["):
#         index = x.startswith("[")
#         print(index)
print(mlist)
# Out:
# 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [43], in <cell line: 2>()
#       1 mlist = []
#       2 for x in f:
# ----> 3     eindex = x.index("[")
#       4     print(eindex)
#       5 #     if x.startswith("["):
#       6 #         index = x.startswith("[")
#       7 #         print(index)
#
# ValueError: substring not found

# %%
file = open("wchat3.txt", "r")
replacement = ""
# using the for loop
for line in file:
    line = line.strip()
    changes = line.replace("\n", "")
    replacement = replacement + changes + "\n"

file.close()
# opening the file in write mode
fout = open("wchat3.txt", "w")
fout.write(replacement)
fout.close()

# %%
#input file
fin = open("wchat2.txt", "rt")
fout = open("out.txt", "wt")
for line in fin:
    fout.write(line.replace('\n', ''))
fin.close()
fout.close()
fin = open("out.txt", "rt")
fout = open("wchat2.txt", "wt")
for line in fin:
    fout.write(line.replace('[', '\n['))
fin.close()
fout.close()
