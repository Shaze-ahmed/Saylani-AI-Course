# %%
import random
Game = ['Rock','Paper','Scissor']
CompPoint= 0
UserPoint = 0
fResult = 0

        
def GetGameResult(x):
    global UserPoint 
    global CompPoint
    
    UserSel = Game[x-1]
    CompSel = random.choice(Game)
    if UserSel == CompSel:
        print(f"Your Select : {UserSel} and Computer Select : {CompSel} =====>>>> Game is Draw !!!")
    elif (UserSel == 'Rock' and CompSel == 'Scissor') or (UserSel == 'Paper' and CompSel == 'Rock') or (UserSel == 'Scissor' and CompSel == 'Paper'):
        print(f"Your Select {UserSel} and Computer Select {CompSel} =====>>>> You Won !!!")
        UserPoint+=1
    else:
        print(f"Your Select : {UserSel} and Computer Select : {CompSel} =====>>>> You Lose !!!")        
        CompPoint+=1
    
while True:
    if int(input("1 for Play the Game, 2 for Exit the Game")) == 2:
        break
    else:
        
        for y in range(3):
            ui = int(input())
            GetGameResult(ui)

        if UserPoint==CompPoint:
            uOut= "Game is Draw !!!!" 
        elif UserPoint>CompPoint:
            uOut= "Hurry!!!! You Won the Game !!!!"
        else:
            uOut= "Ohhh!!! You Lose the Game !!!!"  

    print()
    print("Your Score : ", UserPoint, " and Computer Score : ", CompPoint)
    print(uOut)
#     print(f"Game Result {GetGameResult(ui)}, Your Score is {UserPoint} and Computer Score is {CompPoint}")
# Out:
# 1 for Play the Game, 2 for Exit the Game1
# 1
# Your Select Rock and Computer Select Scissor =====>>>> You Won !!!
# 2
# Your Select : Paper and Computer Select : Scissor =====>>>> You Lose !!!
# 3
# Your Select Scissor and Computer Select Paper =====>>>> You Won !!!
#
# Your Score :  2  and Computer Score :  1
# Hurry!!!! You Won the Game !!!!
# 1 for Play the Game, 2 for Exit the Game2

# %%
import random
Game = ['Rock','Paper','Scissor']
CompPoint= 0
UserPoint = 0
fResult = 0

def CalcResult(num1, num2):
    global UserPoint 
    global CompPoint
    if num1 == num2:
        print(f"Your Select : {num1} and Computer Select : {num2} =====>>>> Game is Draw !!!")
    elif (num1 == 'Rock' and num2 == 'Scissor') or (num1 == 'Paper' and num2 == 'Rock') or (num1 == 'Scissor' and num2 == 'Paper'):
        print(f"Your Select {num1} and Computer Select {num2} =====>>>> You Won !!!")
        UserPoint+=1
    else:
        print(f"Your Select : {num1} and Computer Select : {num2} =====>>>> You Lose !!!")        
        CompPoint+=1
        
def GetGameResult(x):    
    UserSel = Game[x-1]
    CompSel = random.choice(Game)
    CalcResult(UserSel, CompSel)
    
    
while True:
    if int(input("1 for Play the Game, 2 for Exit the Game")) == 2:
        break
    else:
        
        for y in range(3):
            ui = int(input())
            GetGameResult(ui)

        if UserPoint==CompPoint:
            uOut= "Game is Draw !!!!" 
        elif UserPoint>CompPoint:
            uOut= "Hurry!!!! You Won the Game !!!!"
        else:
            uOut= "Ohhh!!! You Lose the Game !!!!"  

    print()
    print("Your Score : ", UserPoint, " and Computer Score : ", CompPoint)
    print(uOut)
# Out:
# 1 for Play the Game, 2 for Exit the Game1
# 2
# Your Select : Paper and Computer Select : Paper =====>>>> Game is Draw !!!
# 3
# Your Select : Scissor and Computer Select : Rock =====>>>> You Lose !!!
# 2
# Your Select Paper and Computer Select Rock =====>>>> You Won !!!
#
# Your Score :  1  and Computer Score :  1
# Game is Draw !!!!
# 1 for Play the Game, 2 for Exit the Game2

# %%
import random
Game = ['Rock','Paper','Scissor']
rList = []
fResult = 0

def CalcResult(num1, num2):
    tempList = []
    if num1 == num2:
        print(f"Your Select : {num1} and Computer Select : {num2} =====>>>> Game is Draw !!!")
    elif (num1 == 'Rock' and num2 == 'Scissor') or (num1 == 'Paper' and num2 == 'Rock') or (num1 == 'Scissor' and num2 == 'Paper'):
        print(f"Your Select {num1} and Computer Select {num2} =====>>>> You Won !!!")
        tempList.append("User")
        tempList.append(1)
    else:
        print(f"Your Select : {num1} and Computer Select : {num2} =====>>>> You Lose !!!")        
        tempList.append('Computer')
        tempList.append(1)        
    rList.append(tuple(tempList))
        
def GetGameResult(x):    
    UserSel = Game[x-1]
    CompSel = random.choice(Game)
    CalcResult(UserSel, CompSel)
    
    
while True:
    if int(input("1 for Play the Game, 2 for Exit the Game")) == 2:
        break
    else:
        
        for y in range(3):
            ui = int(input())
            GetGameResult(ui)
    print(rList)
# Out:
# 1 for Play the Game, 2 for Exit the Game1
# 1
# Your Select : Rock and Computer Select : Paper =====>>>> You Lose !!!
# 2
# Your Select : Paper and Computer Select : Paper =====>>>> Game is Draw !!!
# 3
# Your Select Scissor and Computer Select Paper =====>>>> You Won !!!
# [('Computer', 1), (), ('User', 1)]
# 1 for Play the Game, 2 for Exit the Game2
