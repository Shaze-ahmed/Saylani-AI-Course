# %%
from csv import reader

opened_file = open("artworks.csv", encoding = "utf-8")
read_file = reader(opened_file)
moma = list(read_file)
moma_header = moma[0]
moma = moma[1:]

# %%
# for learning purpose just consider below example of replacing value
age1 = "I am thirty-one years old" 

age2 = age1.replace("thirty-one", "thirty-two")

# %% [markdown]
# # Cleaning Nationality and Gender

# %%
for item in moma:
    nationality = item[2]
    nationality = nationality.replace("(", "")
    nationality = nationality.replace(")", "")
    item[2] = nationality
    
    gender = item[5]
    gender = gender.replace("(", "")
    gender = gender.replace(")", "")
    item[5] = gender

# %%
# replacing empty sting
for item in moma:
    gender = item[5]
    gender = gender.title()
    if gender == "":
        gender = gender.replace("", "Gender Unknown/Other")
    item[5] = gender
    
    nationality = item[2]
    nationality = nationality.title()
    if nationality == "":
        nationality = nationality.replace("","Nationality Unknown")
    item[2] = nationality

# %% [markdown]
# # Cleaning begin and end dates

# %%
def clean_and_convert(date):
    if date != "":
        date = date.replace("(","")
        date = date.replace(")","")
        date = int(date)
    return date

# %%
for item in moma:
    birth_date = item[3]
    death_date = item[4]
    
    birth_date = clean_and_convert(birth_date)
    death_date = clean_and_convert(death_date)
    
    item[3] = birth_date
    item[4] = death_date

# %% [markdown]
# # Cleaning Date column

# %%
test_data = ["1912", "1929", "1913-1923",
             "(1951)", "1994", "1934",
             "c. 1915", "1995", "c. 1912",
             "(1988)", "2002", "1957-1959",
             "c. 1955.", "c. 1970's", 
             "C. 1990-1999"]

bad_chars = ["(",")","c","C",".","s","'", " "]

# %%
def strip_characters(string):
    for char in bad_chars:
        string = string.replace(char,"")
    return string

# %%
for item in moma:
    date = item[6]
    date = strip_characters(date)
    item[6] = date

# %%
def process_date(string):
    if "-" in string:
        string = string.split("-")
        frst_indx = int(string[0])
        sec_indx = int(string[1])
        avg_value = round((frst_indx+sec_indx)/2)
        string = avg_value
    else:
        string = int(string)
    return string

# %%
for item in moma:
    date = item[6]
    date = strip_characters(date)
    date = process_date(date)
    item[6] = date
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-09a371d0d2d0> in <module>
#       2     date = item[6]
#       3     date = strip_characters(date)
# ----> 4     date = process_date(date)
#       5     item[6] = date
#       6
#
# <ipython-input-10-74f1dfe1fbda> in process_date(string)
#       2     if "-" in string:
#       3         string = string.split("-")
# ----> 4         frst_indx = int(string[0])
#       5         sec_indx = int(string[1])
#       6         avg_value = round((frst_indx+sec_indx)/2)
#
# ValueError: invalid literal for int() with base 10: ''

# %%
moma[0:3]

# %% [markdown]
# # Preparing a CSV containing all of the data cleaning I performed, called artworks_clean.csv.

# %%
import csv
f = open("artworks_clean.csv", "w",newline= "",encoding="utf-8")
writer = csv.writer(f, delimiter = ",")
writer.writerow(moma_header)
for item in moma:
    writer.writerow(item)

# %%
from csv import reader

moma = list(reader(open("artworks_clean.csv", encoding = "utf-8")))
moma[0:3]
