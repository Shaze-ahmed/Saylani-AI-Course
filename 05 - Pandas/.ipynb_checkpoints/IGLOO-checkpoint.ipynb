# %%
pip install --upgrade xlrd
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: xlrd in /usr/local/lib/python3.7/dist-packages (1.1.0)
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
#      |████████████████████████████████| 96 kB 3.6 MB/s
# Installing collected packages: xlrd
#   Attempting uninstall: xlrd
#     Found existing installation: xlrd 1.1.0
#     Uninstalling xlrd-1.1.0:
#       Successfully uninstalled xlrd-1.1.0
# Successfully installed xlrd-2.0.1

# %%
import pandas as pd

# %%
igloo = pd.read_excel("IGLOO.xls")
igloo
igloo.to_excel('saved_file.xlsx')
igloo
# Out:
#        SalesDate  SalesQTY  SalesAmount ProductCategory ProductSubCategory  \
# 0     2016-09-01         3       716.33      ICE CREAMS         MOMENT TUB
# 1     2016-09-01        10      2387.78      ICE CREAMS         MOMENT TUB
# 2     2016-01-01        50      1042.05           CONES        2 IN 1 CONE
# 3     2016-01-01        32       666.91            CUPS        CLASSIC CUP
# 4     2016-02-01        24       343.06            CUPS          CHEER CUP
# ...          ...       ...          ...             ...                ...
# 55157 2016-03-01        16       389.03        DryStock   ARJuiceMngo200ml
# 55158 2016-03-01       750     15630.79        DryStock     ARJuiceApple1L
# 55159 2016-07-01        20       547.76        DryStock     ARJuiceBC200ml
# 55160 2016-07-01       160      3334.56        DryStock   AR Juice TC 1.75
# 55161 2016-08-01       750      5210.25        DryStock     ARJuiceTC200ml
#
#                                    ProductName           StoreName  \
# 0                  STRABERY CHEESE CAKE MOMENT  QADRI SUPER MARKET
# 1                     CHOC FUDGE BROWNI MOMENT  QADRI SUPER MARKET
# 2                         KING CONE 2/1 (1X25)        NAGINA STORE
# 3                     MANGO CLASSIC CUP (1X16)        NAGINA STORE
# 4                      CHEER VANILA CUP (1X24)        NAGINA STORE
# ...                                        ...                 ...
# 55157              Al Rawabi Juice Mango 200ml           SELF MART
# 55158                 Al Rawabi Juice Apple 1L          AWAMI COLD
# 55159     Al Rawabi Juice Berry Cocktail 200ml    HAFEEZ GEN.STORE
# 55160  Al Rawabi Juice Tropical Cocktail 1.75L    HAFEEZ GEN.STORE
# 55161  Al Rawabi Juice Tropical Cocktail 200ml          M-R MEDICO
#
#       StoreRegion StoreProvince StoreZone             StoreArea  Unnamed: 11  \
# 0         KARACHI         SINDH    ZONE-C     C.P BARAR SOCIETY          NaN
# 1         KARACHI         SINDH    ZONE-C     C.P BARAR SOCIETY          NaN
# 2         KARACHI         SINDH    ZONE-C        K.P.T HOSPITAL          NaN
# 3         KARACHI         SINDH    ZONE-C        K.P.T HOSPITAL          NaN
# 4         KARACHI         SINDH    ZONE-C        K.P.T HOSPITAL          NaN
# ...           ...           ...       ...                   ...          ...
# 55157     KARACHI         SINDH    ZONE-B     BLOCK-16 F.B AERA          NaN
# 55158     KARACHI         SINDH    ZONE-B           OLD GOLIMAR          NaN
# 55159     KARACHI         SINDH    ZONE-F     MUHAJIR CAMP NO 5          NaN
# 55160     KARACHI         SINDH    ZONE-F     MUHAJIR CAMP NO 5          NaN
# 55161     KARACHI         SINDH    ZONE-C  LADY DEFREN HOSPITAL          NaN
#
#        PaymentTerms                   SalesMan              Route
# 0      Credit (114)          ABDUL RAUF(R.S.O)        ORANGI TOWN
# 1      Credit (114)          ABDUL RAUF(R.S.O)        ORANGI TOWN
# 2      Credit (114)          ABDUL RAUF(R.S.O)        ORANGI TOWN
# 3      Credit (114)          ABDUL RAUF(R.S.O)        ORANGI TOWN
# 4      Credit (114)          ABDUL RAUF(R.S.O)        ORANGI TOWN
# ...             ...                        ...                ...
# 55157  Credit (114)  SYED RASHID ULLAH(R.S.O.)  SHAHFAISAL COLONY
# 55158          Cash  SYED RASHID ULLAH(R.S.O.)  SHAHFAISAL COLONY
# 55159          Cash  SYED RASHID ULLAH(R.S.O.)  SHAHFAISAL COLONY
# 55160          Cash  SYED RASHID ULLAH(R.S.O.)  SHAHFAISAL COLONY
# 55161          Cash  SYED RASHID ULLAH(R.S.O.)  SHAHFAISAL COLONY
#
# [55162 rows x 15 columns]

# %%
igloo.head()
# Out:
#    SalesDate  SalesQTY  SalesAmount ProductCategory ProductSubCategory  \
# 0 2016-09-01         3       716.33      ICE CREAMS         MOMENT TUB
# 1 2016-09-01        10      2387.78      ICE CREAMS         MOMENT TUB
# 2 2016-01-01        50      1042.05           CONES        2 IN 1 CONE
# 3 2016-01-01        32       666.91            CUPS        CLASSIC CUP
# 4 2016-02-01        24       343.06            CUPS          CHEER CUP
#
#                    ProductName           StoreName StoreRegion StoreProvince  \
# 0  STRABERY CHEESE CAKE MOMENT  QADRI SUPER MARKET     KARACHI         SINDH
# 1     CHOC FUDGE BROWNI MOMENT  QADRI SUPER MARKET     KARACHI         SINDH
# 2         KING CONE 2/1 (1X25)        NAGINA STORE     KARACHI         SINDH
# 3     MANGO CLASSIC CUP (1X16)        NAGINA STORE     KARACHI         SINDH
# 4      CHEER VANILA CUP (1X24)        NAGINA STORE     KARACHI         SINDH
#
#   StoreZone          StoreArea  Unnamed: 11  PaymentTerms           SalesMan  \
# 0    ZONE-C  C.P BARAR SOCIETY          NaN  Credit (114)  ABDUL RAUF(R.S.O)
# 1    ZONE-C  C.P BARAR SOCIETY          NaN  Credit (114)  ABDUL RAUF(R.S.O)
# 2    ZONE-C     K.P.T HOSPITAL          NaN  Credit (114)  ABDUL RAUF(R.S.O)
# 3    ZONE-C     K.P.T HOSPITAL          NaN  Credit (114)  ABDUL RAUF(R.S.O)
# 4    ZONE-C     K.P.T HOSPITAL          NaN  Credit (114)  ABDUL RAUF(R.S.O)
#
#          Route
# 0  ORANGI TOWN
# 1  ORANGI TOWN
# 2  ORANGI TOWN
# 3  ORANGI TOWN
# 4  ORANGI TOWN

# %%
product_df = pd.DataFrame(igloo, columns= ['ProductCategory','ProductName','ProductSubCategory'])
product_df.insert(0,'productid',range(1,1+len(product_df)))
product_df
with pd.ExcelWriter("newfile_1.xlsx") as writer:
    igloo.to_excel(writer, "igloo")
    product_df.to_excel(writer, "product_df")
    (store_df).to_excel(writer, "store_df")
    (sales_df).to_excel(writer, "sales_df")
    (salesman_df).to_excel(writer, "salesman_df")

product_df

# %%
store_df = pd.DataFrame(igloo, columns = ['StoreName','StoreRegion','StoreProvince','StoreZone','StoreArea'])
store_df.insert(0,'storeid',range(1,1+len(store_df)))
store_df
# Out:
#        storeid           StoreName StoreRegion StoreProvince StoreZone  \
# 0            1  QADRI SUPER MARKET     KARACHI         SINDH    ZONE-C
# 1            2  QADRI SUPER MARKET     KARACHI         SINDH    ZONE-C
# 2            3        NAGINA STORE     KARACHI         SINDH    ZONE-C
# 3            4        NAGINA STORE     KARACHI         SINDH    ZONE-C
# 4            5        NAGINA STORE     KARACHI         SINDH    ZONE-C
# ...        ...                 ...         ...           ...       ...
# 55157    55158           SELF MART     KARACHI         SINDH    ZONE-B
# 55158    55159          AWAMI COLD     KARACHI         SINDH    ZONE-B
# 55159    55160    HAFEEZ GEN.STORE     KARACHI         SINDH    ZONE-F
# 55160    55161    HAFEEZ GEN.STORE     KARACHI         SINDH    ZONE-F
# 55161    55162          M-R MEDICO     KARACHI         SINDH    ZONE-C
#
#                   StoreArea
# 0         C.P BARAR SOCIETY
# 1         C.P BARAR SOCIETY
# 2            K.P.T HOSPITAL
# 3            K.P.T HOSPITAL
# 4            K.P.T HOSPITAL
# ...                     ...
# 55157     BLOCK-16 F.B AERA
# 55158           OLD GOLIMAR
# 55159     MUHAJIR CAMP NO 5
# 55160     MUHAJIR CAMP NO 5
# 55161  LADY DEFREN HOSPITAL
#
# [55162 rows x 6 columns]

# %%
sales_df = pd.DataFrame(igloo, columns = ["SalesDate","SalesQuantity","SalesAmount"])
sales_df.insert(0,'product_id',range(1,1+len(sales_df)))
sales_df.insert(0,'store_id',range(1,1+len(sales_df)))
sales_df.insert(0,'salesman_id',range(1,1+len(sales_df)))

sales_df
# Out:
#        salesman_id  store_id  product_id  SalesDate  SalesQuantity  \
# 0                1         1           1 2016-09-01            NaN
# 1                2         2           2 2016-09-01            NaN
# 2                3         3           3 2016-01-01            NaN
# 3                4         4           4 2016-01-01            NaN
# 4                5         5           5 2016-02-01            NaN
# ...            ...       ...         ...        ...            ...
# 55157        55158     55158       55158 2016-03-01            NaN
# 55158        55159     55159       55159 2016-03-01            NaN
# 55159        55160     55160       55160 2016-07-01            NaN
# 55160        55161     55161       55161 2016-07-01            NaN
# 55161        55162     55162       55162 2016-08-01            NaN
#
#        SalesAmount
# 0           716.33
# 1          2387.78
# 2          1042.05
# 3           666.91
# 4           343.06
# ...            ...
# 55157       389.03
# 55158     15630.79
# 55159       547.76
# 55160      3334.56
# 55161      5210.25
#
# [55162 rows x 6 columns]

# %%
salesman_df= pd.DataFrame(igloo, columns = ["Salesman","Route","PaymentTerm"])
salesman_df.insert(0,'salesman_id',range(1,1+len(salesman_df)))
salesman_df
# Out:
#        salesman_id  Salesman              Route  PaymentTerm
# 0                1       NaN        ORANGI TOWN          NaN
# 1                2       NaN        ORANGI TOWN          NaN
# 2                3       NaN        ORANGI TOWN          NaN
# 3                4       NaN        ORANGI TOWN          NaN
# 4                5       NaN        ORANGI TOWN          NaN
# ...            ...       ...                ...          ...
# 55157        55158       NaN  SHAHFAISAL COLONY          NaN
# 55158        55159       NaN  SHAHFAISAL COLONY          NaN
# 55159        55160       NaN  SHAHFAISAL COLONY          NaN
# 55160        55161       NaN  SHAHFAISAL COLONY          NaN
# 55161        55162       NaN  SHAHFAISAL COLONY          NaN
#
# [55162 rows x 4 columns]
