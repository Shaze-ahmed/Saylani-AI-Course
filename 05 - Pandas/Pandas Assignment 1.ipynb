# %%
import pandas as pd
import numpy as np
import string

# %%
# Create Dataframe
df = pd.DataFrame(np.random.randint(1, 100000, size = (1000,3)),
                   columns=['X','Y','Z'])
df.tail(10)
# Out:
#          X      Y      Z
# 990  37155  53868  60789
# 991  23821  49452  94429
# 992  71792  25182  30083
# 993  70310  57960  74528
# 994  35598  64582  10340
# 995  23450   9142  18386
# 996  31393  31396  56898
# 997  50863  32914  31882
# 998  44850  80598  35983
# 999   1897  87010   6335

# %%
# Update the Last 10 Rows and X column
df.iloc[990:1000,0] = 5

# %%
df.tail(10)
# Out:
#      X      Y      Z
# 990  5    691  48007
# 991  5  24538  14623
# 992  5  81402  15224
# 993  5  36391  40839
# 994  5  64456  87351
# 995  5  18874  48354
# 996  5  52740  16097
# 997  5  37560  71274
# 998  5  81787  97950
# 999  5  11210  88741

# %%
indDate = pd.date_range("2022-08-20", periods=10)
# alphabet = list(string.ascii_uppercase)
alphabet = [chr(65+i) for i in range(26)]

# %%
df2 = pd.DataFrame(np.random.randint(1, 2600, size = (len(indDate),len(alphabet))),
                   index = indDate,
                   columns = alphabet)

# %%
df2.sort_values(by = ['X','Y'])
# Out:
#                A     B     C     D     E     F     G     H     I     J  ...  \
# 2022-08-26  2543    79   769  2388    76   372   419  1422  1407   432  ...
# 2022-08-21   609   608  1376  2455   396  2075   366  2251  1610  1893  ...
# 2022-08-22   102  1461  1807  1134  2391  2214  1024  1983  2398  2327  ...
# 2022-08-23  1861  1346  1253  2230  1064   955  1312   411  1408  1371  ...
# 2022-08-25  1060   853  1452    86   589  1324  2084  1075  1089  1044  ...
# 2022-08-27   983   517  1520  1428   914  1630  1502   549   562  2594  ...
# 2022-08-24  1237  1569  1517  2332   590  2097  1799  2426  1159  1065  ...
# 2022-08-28  1800  2015   793  2218   419  1969  2151  1683  2354  2116  ...
# 2022-08-20   787   151  1751    56   618  1737  2323  1865  1577  2503  ...
# 2022-08-29  1398   363   767  1246   996   445  2381  1750  2371  1471  ...
#
#                Q     R     S     T     U     V     W     X     Y     Z
# ...

# %%
# alphabet = [chr(65+i) for i in range(26)]
colArray = np.array(alphabet)

# %%
tempList = []
for x in alphabet:
    tempList = []
    for y in alphabet:
        tempList.append(x+y)
    colArray = np.concatenate((colArray, tempList))

# %%
df3 = pd.DataFrame(np.random.randint(1, 2600, size = (len(indDate),len(colArray))),
                   index = indDate,
                   columns = colArray)
df3.head()

# %%
df3.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J',
#        ...
#        'ZQ', 'ZR', 'ZS', 'ZT', 'ZU', 'ZV', 'ZW', 'ZX', 'ZY', 'ZZ'],
#       dtype='object', length=702)

# %%
df.head()
# Out:
#        X      Y      Z
# 0   3018  24205   7543
# 1  20318  31832  71039
# 2   9651  68466  83774
# 3  80799  71603  12495
# 4  66637  36884  34396

# %%
import matplotlib.pyplot  as plt

# %%
df['X'].head(50)
# Out:
# 0      3018
# 1     20318
# 2      9651
# 3     80799
# 4     66637
# 5     10361
# 6     75551
# 7     44345
# 8     21125
# 9     95756
# 10    77537
# 11    41875
# 12    96205
# 13    94532
# 14    16526
# 15    91774
# 16     4768
# 17     8944
# 18    71728
# 19    99872
# 20    95814
# 21    10757
# 22    12277
# 23    97013
# 24    66782
# 25     1162
# 26    49764
# 27    87400
# 28    95399
# 29    24533
# 30    83573
# 31    94291
# 32    92218
# 33    45356
# 34    20456
# 35    53709
# 36     7319
# 37    35040
# 38    32220
# 39     4392
# 40    17813
# 41    92420
# 42    24914
# 43    22857
# 44     5653
# 45     2776
# 46    69089
# 47     5842
# 48    28428
# 49    55668
# Name: X, dtype: int32

# %%
import matplotlib.pyplot  as plt--

# %%
df['X'].head().plot(kind="line")
# Out:
# <AxesSubplot:>

# %%
df['X'].head().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
---
